# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
covid_mobility_us = pd.read_csv('2020_US_Region_Mobility_Report.csv')

# %%
covid_mobility_us
# Out:
#        country_region_code country_region sub_region_1   sub_region_2  \
# 0                       US  United States          NaN            NaN
# 1                       US  United States          NaN            NaN
# 2                       US  United States          NaN            NaN
# 3                       US  United States          NaN            NaN
# 4                       US  United States          NaN            NaN
# ...                    ...            ...          ...            ...
# 812060                  US  United States      Wyoming  Weston County
# 812061                  US  United States      Wyoming  Weston County
# 812062                  US  United States      Wyoming  Weston County
# 812063                  US  United States      Wyoming  Weston County
# 812064                  US  United States      Wyoming  Weston County
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 0              NaN             NaN               NaN
# ...

# %%
covid_mobility_us = covid_mobility_us.rename(columns={"sub_region_1": "NAME"})

# %%
covid_mobility_us
# Out:
#        country_region_code country_region     NAME   sub_region_2  metro_area  \
# 0                       US  United States      NaN            NaN         NaN
# 1                       US  United States      NaN            NaN         NaN
# 2                       US  United States      NaN            NaN         NaN
# 3                       US  United States      NaN            NaN         NaN
# 4                       US  United States      NaN            NaN         NaN
# ...                    ...            ...      ...            ...         ...
# 812060                  US  United States  Wyoming  Weston County         NaN
# 812061                  US  United States  Wyoming  Weston County         NaN
# 812062                  US  United States  Wyoming  Weston County         NaN
# 812063                  US  United States  Wyoming  Weston County         NaN
# 812064                  US  United States  Wyoming  Weston County         NaN
#
# ...

# %% [markdown]
# # CALIFORNIA

# %%
california = covid_mobility_us[covid_mobility_us["NAME"] == "California"]

# sns.histplot(data = california, x = 'parks_percent_change_from_baseline')

# %%
california.drop(columns = ["place_id","iso_3166_2_code"])
# Out:
#       country_region_code country_region        NAME sub_region_2  metro_area  \
# 48065                  US  United States  California          NaN         NaN
# 48066                  US  United States  California          NaN         NaN
# 48067                  US  United States  California          NaN         NaN
# 48068                  US  United States  California          NaN         NaN
# 48069                  US  United States  California          NaN         NaN
# ...                   ...            ...         ...          ...         ...
# 65846                  US  United States  California  Yuba County         NaN
# 65847                  US  United States  California  Yuba County         NaN
# 65848                  US  United States  California  Yuba County         NaN
# 65849                  US  United States  California  Yuba County         NaN
# 65850                  US  United States  California  Yuba County         NaN
#
# ...

# %%
sns.histplot(california, x = "parks_percent_change_from_baseline")
# Out:
# <AxesSubplot:xlabel='parks_percent_change_from_baseline', ylabel='Count'>

# %%
ax_cali = sns.lineplot(x = "date", y = "parks_percent_change_from_baseline", data = california)
# ax.set_xticklabels(ax.get_xticklabels(),rotation = -30)

for ind, label in enumerate(ax_cali.get_xticklabels()):
    if ind % 70 == 0:  # every 14th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)

# %% [markdown]
# # US Dataset

# %%
us_grouped_by_date = covid_mobility_us.groupby("date").agg("mean")
# sns.histplot(covid_mobility_us, x = "parks_percent_change_from_baseline")
us_mobility = us_grouped_by_date.reset_index()
us_mobility
# Out:
#            date  metro_area  census_fips_code  \
# 0    2020-02-15         NaN      30383.006250
# 1    2020-02-16         NaN      30472.464111
# 2    2020-02-17         NaN      30274.126093
# 3    2020-02-18         NaN      30241.013955
# 4    2020-02-19         NaN      30237.693294
# ..          ...         ...               ...
# 316  2020-12-27         NaN      30696.831094
# 317  2020-12-28         NaN      30209.797023
# 318  2020-12-29         NaN      30234.491178
# 319  2020-12-30         NaN      30211.723902
# 320  2020-12-31         NaN      30183.584262
#
#      retail_and_recreation_percent_change_from_baseline  \
# 0                                             6.438312
# 1                                             7.986545
# 2                                             3.865924
# 3                                            -0.193126
# 4                                             2.079837
# ..                                                 ...
# ...

# %%
sns.histplot(us_mobility, x = "parks_percent_change_from_baseline", bins = 50)
plt.title("Parks Percent Change from Baseline in the US")
plt.xlabel("percent change")
# Out:
# Text(0.5, 0, 'percent change')

# %%
ax_grouped = sns.lineplot(x = "date", y = "parks_percent_change_from_baseline", data = us_mobility)

for ind, label in enumerate(ax_grouped.get_xticklabels()):
    if ind % 70 == 0:  # every 70th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
        
plt.title("Parks Percent Changes Throughout 2020")
# Out:
# Text(0.5, 1.0, 'Parks Percent Changes Throughout 2020')

# %%
# closer look during lockdown


after_03_1 = us_mobility[us_mobility["date"] > "2020-03-01"]
before_june_1 = after_03_1[after_03_1["date"] < "2020-06-02"]
ax_before_june_1 = sns.lineplot(x = "date", y = "parks_percent_change_from_baseline", data = before_june_1)

for ind, label in enumerate(ax_before_june_1.get_xticklabels()):
    if ind % 20 == 0:  # every 20th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)

# %% [markdown]
# # California right before lockdown 3/19

# %% [markdown]
# https://abc7news.com/timeline-of-coronavirus-us-covid-19-bay-area-sf/6047519/

# %%
california[california["parks_percent_change_from_baseline"] == min(california["parks_percent_change_from_baseline"])]
# Out:
#       country_region_code country_region        NAME     sub_region_2  \
# 54696                  US  United States  California  Mariposa County
#
#        metro_area iso_3166_2_code  census_fips_code  \
# 54696         NaN             NaN            6043.0
#
#                           place_id        date  \
# 54696  ChIJey7XBpaFloARsZQNIKqDzZo  2020-04-05
#
#        retail_and_recreation_percent_change_from_baseline  \
# 54696                                              -86.0
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 54696                                              -54.0
#
#        parks_percent_change_from_baseline  \
# 54696                               -87.0
#
#        transit_stations_percent_change_from_baseline  \
# 54696                                            NaN
#
#        workplaces_percent_change_from_baseline  \
# 54696                                    -53.0
#
#        residential_percent_change_from_baseline
# ...

# %%
after_03_1 = california[california["date"] > "2020-03-01"]
before_june_1 = after_03_1[after_03_1["date"] < "2020-06-02"]
ax_cali_before_june_1 = sns.lineplot(x = "date", y = "parks_percent_change_from_baseline", data = before_june_1)

for ind, label in enumerate(ax_cali_before_june_1.get_xticklabels()):
    if ind % 20 == 0:  # every 20th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
        
plt.title("California Parks Percent Change from Baseline March to May")
plt.ylabel("Parks Percent Change")
# Out:
# Text(0, 0.5, 'Parks Percent Change')

# %%
cali_ax = sns.lineplot(x = "date", y = "parks_percent_change_from_baseline", data = california)

for ind, label in enumerate(cali_ax.get_xticklabels()):
    if ind % 70 == 0:  # every 70th label is kept
        label.set_visible(True)
    else:
        label.set_visible(False)
        
plt.title("Parks Percent Changes Throughout 2020 in California")
# Out:
# Text(0.5, 1.0, 'Parks Percent Changes Throughout 2020 in California')

# %%
df = pd.read_csv('2020_US_Region_Mobility_Report.csv')

# %%
df = df.rename(columns={"sub_region_1": "NAME"})
df = df.groupby('NAME').mean()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                       metro_area  census_fips_code  \
# NAME
# Alabama                      NaN       1066.835217
# Alaska                       NaN       2129.660021
# Arizona                      NaN       4013.954836
# Arkansas                     NaN       5074.790856
# California                   NaN       6058.532551
# Colorado                     NaN       8061.825545
# Connecticut                  NaN       9008.000000
# Delaware                     NaN      10003.000000
# District of Columbia         NaN      11001.000000
# Florida                      NaN      12068.086980
# Georgia                      NaN      13157.841169
# Hawaii                       NaN      15005.000000
# Idaho                        NaN      16045.869267
# Illinois                     NaN      17103.122373
# Indiana                      NaN      18091.207842
# Iowa                         NaN      19099.905522
# Kansas                       NaN      20099.419714
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b973bf52-720f-4f08-a354-6907a41c78da' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
